# %%
import pandas as pd
from tpot import TPOTClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
import numpy as np
from sklearn import metrics
from sklearn.metrics import make_scorer
import warnings
warnings.filterwarnings('ignore')
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from lightgbm import LGBMClassifier
import shap
# Out:
# /usr/local/anaconda3/envs/bpce/lib/python3.8/site-packages/tpot/builtins/__init__.py:36: UserWarning: Warning: optional dependency `torch` is not available. - skipping import of NN models.
#   warnings.warn("Warning: optional dependency `torch` is not available. - skipping import of NN models.")

# %%
df = pd.read_csv('credit_default_clients.csv', sep=';')

# %%
df = df.rename(columns={'default payment next month': "default"})
y = df["default"]
var = [col for col in list(df.columns) if col != "default"]
X = df[var]

X_train, X_test, y_train, y_test = train_test_split(X.astype(np.float64),
    y.astype(np.float64), train_size=0.75, test_size=0.25, random_state=42)

rf = RandomForestClassifier(max_depth=5, n_estimators=10,
                                        n_jobs=-1)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=10, n_jobs=-1)

# %%
lgbm = LGBMClassifier()
lgbm.fit(X_train,y_train)
# Out:
# LGBMClassifier()

# %%
explainer = shap.Explainer(lgbm, X)
shap_values = explainer(X)
# Out:
#  99%|===================| 29697/30000 [01:24<00:00]

# %%
import xgboost
import shap

# train XGBoost model
X,y = shap.datasets.adult()
model = xgboost.XGBClassifier().fit(X, y)

# compute SHAP values
explainer = shap.TreeExplainer(model = model, data = X, model_output="probability")
shap_values = explainer(X)
# Out:
#  99%|===================| 32342/32561 [01:42<00:00]

# %%
model.predict_proba(X)
# Out:
# array([[9.9723214e-01, 2.7678353e-03],
#        [7.8412294e-01, 2.1587703e-01],
#        [9.8936468e-01, 1.0635338e-02],
#        ...,
#        [9.5627624e-01, 4.3723788e-02],
#        [9.9978966e-01, 2.1033324e-04],
#        [2.1892786e-04, 9.9978107e-01]], dtype=float32)

# %%
shap_values[0].values
# Out:
# array([ 0.00020816, -0.01885998,  0.00543376, -0.0222181 , -0.01161756,
#        -0.03830801, -0.00085049,  0.00619621, -0.12916337, -0.01623346,
#        -0.0133245 ,  0.00083996])

# %%
 l = shap.plots.bar(shap_values)

# %%
means = list(np.abs(shap_values.values).mean(axis = 0))
means = [round(mean,3) for mean in means]

# %%
shap_values.feature_names
# Out:
# ['Age',
#  'Workclass',
#  'Education-Num',
#  'Marital Status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Capital Gain',
#  'Capital Loss',
#  'Hours per week',
#  'Country']

# %%
shap_values.feature_names
# Out:
# ['Age',
#  'Workclass',
#  'Education-Num',
#  'Marital Status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Capital Gain',
#  'Capital Loss',
#  'Hours per week',
#  'Country']

# %%
import plotly.graph_objects as go

x_axis = list(shap_values[0].values) 
base_x = shap_values[0].base_values


y_axis = ["{} = {}".format(name,val)for (name,val) in zip(shap_values.feature_names,list(shap_values[0].data))]
base_y = "moyenne"


dic_x_y = { y:x for (y,x) in zip (y_axis, x_axis)}


pd.DataFrame(values = [x_axis, y_axis], columns= ['x','y'])

fig = go.Figure(data = [go.Bar(
            x= x_axis,
            y=y_axis,
            name = "Impacts négatifs",
            orientation='h',
            marker_color = "darkred",
            text=x_axis),
                       ],
            )
fig.update_traces(
                  textposition='outside',
                 textfont_size=14)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-128-2bdf78494c0a> in <module>
#      19 x_neg = sorted(x_neg)
#      20
# ---> 21 pd.DataFrame(values = [x_axis, y_axis], columns= ['x','y'])
#      22
#      23 fig = go.Figure(data = [go.Bar(
#
# TypeError: __init__() got an unexpected keyword argument 'values'

# %%
df_means = pd.DataFrame()

y_axis_means = list(shap_values.feature_names)
means = list(np.abs(shap_values.values).mean(axis = 0))
means = [round(mean,3) for mean in means]

df_means['y'] = y_axis
df_means['mean'] = means
df_means = df_means.sort_values(by = 'y', ascending= False)

fig = go.Figure(data = [go.Bar(
            x= df_means['mean'],
            y=df_means['y'],
            name = "Impacts sur le score",
            orientation='h',
            marker_color = "Navy",
            text=df_means['mean'],
            opacity = 0.7),
            
                       ],
            )
fig.update_traces(
                  textposition='auto',
                 textfont_size=12)
fig.update_layout(
    autosize=True,
    title={
        'text': "Impact Absolu Global",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'}
    )
fig.show()
# Out:
# <div>                            <div id="dc46b603-40f7-4ad4-bc4e-059bdfe37d33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc46b603-40f7-4ad4-bc4e-059bdfe37d33")) {                    Plotly.newPlot(                        "dc46b603-40f7-4ad4-bc4e-059bdfe37d33",                        [{"marker": {"color": "Navy"}, "name": "Impacts sur le score", "opacity": 0.7, "orientation": "h", "text": [0.008, 0.012, 0.062, 0.004, 0.036, 0.039, 0.031, 0.044, 0.003, 0.026, 0.052, 0.049], "textfont": {"size": 12}, "textposition": "auto", "type": "bar", "x": [0.008, 0.012, 0.062, 0.004, 0.036, 0.039, 0.031, 0.044, 0.003, 0.026, 0.052, 0.049], "y": ["Workclass = 7.0", "Sex = 1.0", "Relationship = 0.0", "Race = 4.0", "Occupation = 1.0", "Marital Status = 4.0", "
# ...

# %%
df = pd.DataFrame()

x_axis = list(shap_values[0].values) 
base_x = shap_values[0].base_values


x_axis = [round(x,3) for x in x_axis]
df['x'] = x_axis
df['y'] = y_axis

base_x = shap_values[0].base_values
base_y = "Moyenne du modèle"
df2 = pd.DataFrame()
df2['x'] = [round(base_x,3)]
df2['y'] = [base_y]

df = df.sort_values(by = 'y', ascending= False)
df = df2.append(df)
df["Color"] = np.where(df["x"]<0, 'darkred', 'RoyalBlue')
fig = go.Figure(data = [go.Bar(
            x= df['x'],
            y=df['y'],
            name = "Impacts sur le score",
            orientation='h',
            marker_color = df['Color'],
            text=df['x'],
            opacity = 0.7),
            
                       ],
            )
fig.update_traces(
                  textposition='auto',
                 textfont_size=12)
fig.update_layout(
    autosize=True,
    )
fig.show()
# Out:
# <div>                            <div id="d06060f4-c1b4-4c66-a669-60cc58a2880a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d06060f4-c1b4-4c66-a669-60cc58a2880a")) {                    Plotly.newPlot(                        "d06060f4-c1b4-4c66-a669-60cc58a2880a",                        [{"marker": {"color": ["RoyalBlue", "darkred", "RoyalBlue", "darkred", "darkred", "darkred", "darkred", "darkred", "RoyalBlue", "RoyalBlue", "darkred", "darkred", "RoyalBlue"]}, "name": "Impacts sur le score", "opacity": 0.7, "orientation": "h", "text": [0.241, -0.019, 0.006, -0.038, -0.001, -0.012, -0.022, -0.013, 0.005, 0.001, -0.016, -0.129, 0.0], "textfont": {"size": 12}, "textposition": "auto", "type": "bar", "x": [0.241, -0.019, 0.006, -0.038, -0.001, -0.012
# ...

# %%
df
# Out:
#         x                      y    Color
# 0   0.000             Age = 39.0     navy
# 8  -0.129  Capital Gain = 2174.0  darkred
# 9  -0.016     Capital Loss = 0.0  darkred
# 11  0.001         Country = 39.0     navy
# 2   0.005   Education-Num = 13.0     navy
# 10 -0.013  Hours per week = 40.0  darkred
# 3  -0.022   Marital Status = 4.0  darkred
# 4  -0.012       Occupation = 1.0  darkred
# 6  -0.001             Race = 4.0  darkred
# 5  -0.038     Relationship = 0.0  darkred
# 7   0.006              Sex = 1.0     navy
# 1  -0.019        Workclass = 7.0  darkred

# %%
shap_values[0].base_values
# Out:
# -2.6846917539397146

# %%
l = ["relative", "relative", "relative", "relative", "total", "relative",
                                              "relative", "relative", "relative", "total", "relative", "relative", "total", "relative", "total"]

e

# %%
fig = go.Figure(go.Waterfall(
    name = "2018", orientation = "h", measure = ['total']*len(l),
    y = ["Sales", "Consulting", "Maintenance", "Other revenue", "Net revenue", "Purchases", "Material expenses",
       "Personnel expenses", "Other expenses", "Operating profit", "Investment income", "Financial income",
       "Profit before tax", "Income tax (15%)", "Profit after tax"],
    x = [375, 128, 78, 27, None, -327, -12, -78, -12, None, 32, 89, None, -45, None],
    connector = {"mode":"between", "line":{"width":4, "color":"rgb(0, 0, 0)", "dash":"solid"}}
))

fig.update_layout(title = "Profit and loss statement 2018")

fig.show()
# Out:
# <div>                            <div id="210d68af-dccc-4fc6-9b73-127b773c2196" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("210d68af-dccc-4fc6-9b73-127b773c2196")) {                    Plotly.newPlot(                        "210d68af-dccc-4fc6-9b73-127b773c2196",                        [{"connector": {"line": {"color": "rgb(0, 0, 0)", "dash": "solid", "width": 4}, "mode": "between"}, "measure": ["total", "total", "total", "total", "total", "total", "total", "total", "total", "total", "total", "total", "total", "total", "total"], "name": "2018", "orientation": "h", "type": "waterfall", "x": [375, 128, 78, 27, null, -327, -12, -78, -12, null, 32, 89, null, -45, null], "y": ["Sales", "Consulting", "Maintenance", "Other revenue", "Net revenue", "Pur
# ...

# %%
bar_plot(shap_values[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-9f7a1218d834> in <module>
# ----> 1 bar_plot(shap_values[0])
#
# /usr/local/anaconda3/envs/bpce/lib/python3.8/site-packages/shap/plots/bar.py in bar_plot(shap_values, features, feature_names, max_display, show)
#
# /usr/local/anaconda3/envs/bpce/lib/python3.8/site-packages/shap/plots/bar.py in <listcomp>(.0)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
shap.force_plot(explainer.expected_value, shap_values[0,:], X_train.iloc[0,:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-7cf521da0098> in <module>
# ----> 1 shap.force_plot(explainer.expected_value, shap_values[0,:], X_train.iloc[0,:])
#       2
#       3
#       4
#
# TypeError: list indices must be integers or slices, not tuple
